# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('usgs_train_mini.csv')

# %%
keys = np.array(df.keys())
get = keys[ [4,5,6,7,8] ]
df_get = df[get]

# %%
sns.pairplot(df_get)

# %%
df_get[ ['label:USGS:discharge_mean', 'sequence:USGS:discharge_mean'] ]
# Out:
#       label:USGS:discharge_mean  sequence:USGS:discharge_mean
# 0                      0.088053                      2.916301
# 1                      0.088053                      2.254146
# 2                      0.088053                      1.535637
# 3                      0.088053                      1.091852
# 4                      0.088053                      0.824172
# 5                      0.088053                      0.689628
# 6                      0.088053                      0.686810
# 7                      0.088053                      0.601575
# 8                      0.088053                      0.687515
# 9                      0.088053                      4.677353
# 10                     0.088053                      4.381496
# 11                     0.088053                      2.810638
# 12                     0.088053                      6.163681
# 13                     0.088053                     11.482057
# ...

# %%
list(lol.iterrows())[:80]
# Out:
# [(0, label:USGS:discharge_mean       0.088053
#   sequence:USGS:discharge_mean    2.916301
#   Name: 0, dtype: float64), (1, label:USGS:discharge_mean       0.088053
#   sequence:USGS:discharge_mean    2.254146
#   Name: 1, dtype: float64), (2, label:USGS:discharge_mean       0.088053
#   sequence:USGS:discharge_mean    1.535637
#   Name: 2, dtype: float64), (3, label:USGS:discharge_mean       0.088053
#   sequence:USGS:discharge_mean    1.091852
#   Name: 3, dtype: float64), (4, label:USGS:discharge_mean       0.088053
#   sequence:USGS:discharge_mean    0.824172
#   Name: 4, dtype: float64), (5, label:USGS:discharge_mean       0.088053
#   sequence:USGS:discharge_mean    0.689628
#   Name: 5, dtype: float64), (6, label:USGS:discharge_mean       0.088053
#   sequence:USGS:discharge_mean    0.686810
#   Name: 6, dtype: float64), (7, label:USGS:discharge_mean       0.088053
#   sequence:USGS:discharge_mean    0.601575
# ...

# %%
df
# Out:
#       Unnamed: 0  Unnamed: 0.1  __site_id __state_name  \
# 0              0             0    1010000           ME
# 1              1             1    1010000           ME
# 2              2             2    1010000           ME
# 3              3             3    1010000           ME
# 4              4             4    1010000           ME
# 5              5             5    1010000           ME
# 6              6             6    1010000           ME
# 7              7             7    1010000           ME
# 8              8             8    1010000           ME
# 9              9             9    1010000           ME
# 10            10            10    1010000           ME
# 11            11            11    1010000           ME
# 12            12            12    1010000           ME
# 13            13            13    1010000           ME
# 14            14            14    1010000           ME
# 15            15            15    1010000           ME
# ...
